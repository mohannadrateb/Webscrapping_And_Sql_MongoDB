# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.datajob.io/'
page = requests.get(url)
soup = BeautifulSoup(page.text,'html')

# %%
divs = soup.find_all('div', class_='content_card-block')

# %%
job_names =[]
company_names=[]
job_descs =[]
job_infos= []
for div in divs:
    job_info_array =[]
    nested_div_job_name = div.find('div', class_='content_card-title')
    nested_div_job_name = nested_div_job_name.text.strip() 
    nested_div_company_name = div.find('div', class_='content_card-company-name')
    nested_div_company_name = nested_div_company_name.text.strip()
    nested_div_job_desc = div.find('div', class_='content-card-div-job-desc').text.strip()
    nested_div_job_info = div.find_all('div', class_='content_card-location-ff-salary')
    for job in nested_div_job_info:
        nested_div_job_info = job.find_all('div', class_='content_card-info-text')
        for job_info in nested_div_job_info:
            #print(job_info.text.strip())
            job_info_array.append(job_info.text.strip())
    
    #print(nested_div_job_name)
    #print(nested_div_company_name)
    #print(nested_div_job_desc)
    #print(nested_div_job_info)
    #print(nested_div_job_req)
    job_names.append(nested_div_job_name)
    company_names.append(nested_div_company_name )
    job_descs.append(nested_div_job_desc)
    job_infos.append(job_info_array)




    #break

# %%
print(job_names)
print("--------------------")
print(company_names)
print('-----------------------')
print(job_descs)
print('-------------------')
print(job_infos)
# Out:
# ['Senior Data Analyst, Business Analytics (Supply Acquisition)', 'Applied Scientist (MT), ASIN Localization', 'AI Research Scientist', 'Data Analyst Supply Chain (m/w/d) - Gigafactory', 'Data Engineer - Partner Tech', 'Data Engineer, Amazon Deals', 'Data Scientist', 'Senior Data Analyst - Customer Experience Analytics (all genders)', 'Data Engineer', 'Data Engineer - Customer Fulfillment BI', 'Senior Data Engineer (Experimentation Platform)', 'Junior Data Scientist', 'Data Scientist', 'Sr. Pricing Data Scientist/Analyst', '(Senior) Data Analyst - Allianz Direct', 'Data Engineer - Zalando Marketing Services', 'Senior Applied Researcher', 'Business Intelligence Analyst', 'Data Analyst / Decision Scientist, Network', '(Junior) Data Engineer', 'Data Engineer', 'Data / ML Engineer - Performance Marketing', 'Data Scientist â\x80\x93 Bidding and Recommendations', 'Senior Data Analyst, Marketing/Measurement', 'Senior Data / Product Analyst in Performance Marketing', 'Data Engineer â\x80\x93 Content', 'Senior Applied Scientist - Customer Relationship Management (CRM)', 'Sr Data Engineer - CRM', 'Applied Researcher', 'Senior Data Analyst', 'Senior Data Scientist, Courier Earnings', 'Senior Data Scientist', 'Senior Data / Product Analyst in CRM / Customer Inbox', 'Data Engineer (F/M/D) - Marketing', 'Senior Data Engineer for Partner Tech', 'Research Scientist', 'Senior Data Scientist', 'Analytics Engineer (Data Governance) (m/f/d)', 'Data Engineer', 'Senior Data Engineer', 'Software / Machine Learning Engineer - Map Data', 'Data Engineer (Mid/Senior) - Machine Learning Engineering - Markets', 'Senior Big Data Engineer Hadoop & Cloud', 'Research Engineer - Automatic Speech Recognition', 'Senior Applied Scientist', 'Senior Data Engineer for Lounge by Zalando', '(Senior) Data Scientist - Credit Risk', 'Senior Applied Scientist - Marketing Services', 'Data Engineer - Demand Offer Data Platform - Markets', 'Senior Engineer in Data & Machine Learning', 'Imaging Scientist - Hardware Test Engineering Group', 'Senior Data Engineer - Experimentation Platform', '(Junior) Data Scientist', 'Junior Data Scientist', '(Senior) Analytics Engineer / Data Engineer', 'Senior Big Data Engineer', 'Senior Data Engineer', 'Senior Applied Scientist', 'Senior Applied Scientist', 'Applied Scientist (Marketing Intelligence)', 'Senior Data Scientist']
# --------------------
# ['Get Your Guide', 'Amazon', 'Autodesk', 'Tesla', 'Zalando', 'Amazon', 'Billie', 'Zalando', 'Omio', 'Zalando', 'Get Your Guide', 'Adidas', 'DocMorris', 'Grover', 'Allianz', 'Zalando', 'eBay', 'adjoe', 'Vinted', 'home24', 'home24', 'Zalando', 'Trivago', 'Get Your Guide', 'Zalando', 'Trivago', 'Zalando', 'Zalando', 'eBay', 'SumUp', 'Wolt', 'Sixt', 'Zalando', 'IONOS', 'Zalando', 'DeepL', 'Microsoft', 'Omio', 'DeepL', 'Zalando', 'Lyft', 'Zalando', 'Deutsche Bank', 'SONY', 'Zalando', 'Zalando', 'home24', 'Zalando', 'Zalando', 'Zalando', 'Apple', 'Zalando', 'Check 24', 'Allianz Health Digital', 'TeamViewer', 'AMADEUS', 'epilot', 'Zalando', 'Zalando', 'Zalando', 'adjoe']
# -----------------------
# ["*What you'll do: You will be focusing on uncovering opportunities and influencing the supply acquisition strategy.", "*What you'll do: You will focus on delivering optimal translation quality for product data at a massive scale.", "*What you'll do: You will be doing fundamental and applied research in AI.", "*What you'll do: You will be working on delivering process improvements, systems capabilities, and data insights for Direct Supply Chain components and materials team.", "*What you'll do: You will support the implementation of a reliable and performant data infrastructure that integrates with internal and 3rd party tools.", "*What you'll do: You will work closely with cross-functional teams to implement data pipelines, ETL processes, data modeling, and best practices.", "*What you'll do: You will be building and implementing fraud detection models across different portfolios.", "*What you'll do: You will be working with customer experience, extracting insights and translating them into actionable recommendations.", "*What you'll do: You will be working on maintaining and improving data ingestion platform.", "*What you'll do: You will be responsible for designing and implementing scalable data pipelines that are essential for supporting the expansion of the data warehouse.", "*What you'll do: You will design and implement features in the A/B experimentation platform with scalable and efficient data and software engineering practices.", "*What you'll do: You will be working on the recommendation algorithm improvements.", "*What you'll do: You will be working on smart/optimization/personalisation algorithms, recommender systems, forecasting and predictive models.", "*What you'll do: You will be working on building and improving pricing engine.", "*What you'll do: You will be part of Finance function at Allianz Directand provide key stakeholders with appropriate information, analyses and recommendations to steer the company on a value-based approach.", "*What you'll do: You will develop and further enhance Zalando's self-service web interfaces.", "*What you'll do: You will be working on the next generation of online advertising and search ranking products in eBay search.", "*What you'll do: You will be working on creating, analyzing and communicating reports and statistics for the business teams and partners.", "*What you'll do: You will be working on performance metrics for carrier portfolio, automation of carrier tracking, ways to optimise the services provided.", "*What you'll do: You will be working on designing, implementing and maintaining data processing pipelines in different clouds.", "*What you'll do: You will be working on designing, implementing and maintaining data processing pipelines in different clouds.", "*What you'll do: You will be working on Implementing and maintaining high-performance and growth-ready data-processing and data integration pipelines.", "*What you'll do: You will design, implement, and improve our bidding algorithms and evaluate their performance on live data.", "*What you'll do: You will be helping to improve and to create measurement tools to determine the ROI of the performance marketing campaigns.", "*What you'll do: You will ensure a consistent and sustainable channel performance and profitable growth.", "*What you'll do: You will process and deliver high quality content, by utilizing modern cloud technologies for batch and stream data processes.", "*What you'll do: You will analyse client behaviour and develop targeted communication strategies.", "*What you'll do: You will develop, monitor, and operate data integration pipelines, deployed as applications on a PaaS/SaaS cloud.", '*Ebay is a global e-commerce marketplace. You will work on such diverse projects as Image Quality scoring; Automatic Taxonomy Improvement and more.', '*SumUp is a top payments company in Germany. You will analyze data, create insights, and build user-friendly dashboards to support product research, strategy,  ...
# -------------------
# [['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Spark, SQL', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, TensorFlow', 'Hybrid'], ['Munich, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, TensorFlow', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Tableau', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, AWS, Airflow', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Scala, AWS, Hadoop', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, R, SQL,', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Spark, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Airflow, Terraform', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, AWS, Databricks', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Scala', 'Hybrid'], ['Herzogenaurach, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Spark', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL', 'Hybrid'], ['Munich, DE', 'Visa sponsorship', 'in English', 'Power BI, Python, SQL', 'On-site only'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, AWS, Databricks', 'Hybrid'], ['Kleinmachnow, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Spark', 'Hybrid'], ['Hamburg, DE', 'Visa sponsorship', 'in English', 'Python, SQL, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Looker', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Scala, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Scala, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, AWS, Databricks', 'Hybrid'], ['DÃ¼sseldorf, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Spark', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Looker', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL', 'Hybrid'], ['DÃºsseldorf, DE', 'Visa sponsorship', 'in English', 'Python, BigQuery, Kafka', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, PySpark', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Scala, Spark, AWS', 'Hybrid'], ['Kleinmachnow, DE', 'Visa sponsorship', 'in English', 'Python, Spark, PyTorch', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Snowflake, SQL, Tableau', 'On-site only'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Snowflake', 'Remote'], ['Munich, DE', 'Visa sponsorship', 'in English', 'Python, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Java, SQL, Data Vault 2.0', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Spark, Databricks, Airflow, MPP DW', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, C++, PyTorch, Tensorflow', 'Remote'], ['DE', 'Visa sponsorship', 'in English', 'Python, C++, Spark', 'Remote'], ['Berlin, DE', 'Apply from abroad', 'in English', 'GCP, Airflow, Spark, Terraform, ks8', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, SQL, Clickhouse, Kubernetes', 'Remote'], ['Munich, DE', 'Visa sponsorship', 'in English', 'Airflow, AWS, Terraform, Python, SQL', 'Hybrid'], ['Munich, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, Spark, Airflow, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'SQL, Hadoop, Google Cloud', 'Hybrid'], ['Stuttgart, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, PySpark, AWS', 'Hybrid'], ['Berlin, DE', 'Visa sponsorship', 'in English', 'MPP, Python, AWS,  ...

# %%
import pandas as pd
df = pd.DataFrame(columns = ['company_name','job_name','job_desc','job_req_and_info'])

# %%
df['company_name'] = company_names
df['job_name'] = job_names
df ['job_desc'] = job_descs
df['job_req_and_info'] =job_infos

# %%
import ast
def concatenate_array(arr):
     print("this is the input")
     arr = ast.literal_eval(arr)
     print(type(arr))
     return ' '.join(map(str, arr))

def turn_to_string(array):
    print("this is the input")
    print(array)
    job_info_string = ""
    for job_info in array:
        print (job_info)
        job_info_string = job_info_string +" "+ job_info+","
    print("---------------")    
    print(job_info_string )
    print("--------------")    
    #return job_info_string


        
#turn_to_string(['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, TensorFlow', 'Hybrid'])
df = df['job_req_and_info'] = df['job_req_and_info'].apply(lambda x: concatenate_array(x))
# Out:
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'str'>
# this is the input
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/3t/srbbc0_s0h30vw6xqx3lt2r00000gq/T/ipykernel_45836/157732756.py in <module>
#      19
#      20 #turn_to_string(['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, TensorFlow', 'Hybrid'])
# ---> 21 df = df['job_req_and_info'] = df['job_req_and_info'].apply(lambda x: concatenate_array(x))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/3t/srbbc0_s0h30vw6xqx3lt2r00000gq/T/ipykernel_45836/157732756.py in <lambda>(x)
#      19
#      20 #turn_to_string(['Berlin, DE', 'Visa sponsorship', 'in English', 'Python, PyTorch, TensorFlow', 'Hybrid'])
# ---> 21 df = df['job_req_and_info'] = df['job_req_and_info'].apply(lambda x: concatenate_array(x))
#
# /var/folders/3t/srbbc0_s0h30vw6xqx3lt2r00000gq/T/ipykernel_45836/157732756.py in concatenate_array(arr)
#       2      print("this is the input")
#       3      print(type(arr))
# ----> 4      return ' '.join(map(str, arr))
#       5
#       6 def turn_to_string(array):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __repr__(self)
#    1469             min_rows=min_rows,
#    1470             max_rows=max_rows,
# -> 1471             length=show_dimensions,
#    1472         )
#    1473         return buf.getvalue()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1532             max_rows=max_rows,
#    1533         )
# -> 1534         result = formatter.to_string()
#    1535
#    1536         # catch contract violations
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     389
#     390         fmt_index, have_header = self._get_formatted_index()
# --> 391         fmt_values = self._get_formatted_values()
#     392
#     393         if self.is_truncated_vertically:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatted_values(self)
#     378             float_format=self.float_format,
#     379             na_rep=self.na_rep,
# --> 380             leading_space=self.index,
#     381         )
#     382
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1332         for i, v in enumerate(vals):
#    1333             if not is_float_type[i] and leading_space:
# -> 1334                 fmt_values.append(f" {_format(v)}")
#    1335             elif is_float_type[i]:
#    1336                 fmt_values.append(float_format(v))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _format(x)
#    1309                 return self.na_rep
#    1310             elif isinstance(x, PandasObject):
# -> 1311                 return str(x)
#    1312             else:
#    1313                 # object dtype
#
# ... last 8 frames repeated, from the frame below ...
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __repr__(self)
#    1469             min_rows=min_rows,
#    1470             max_rows=max_rows,
# -> 1471             length=show_dimensions,
#    1472         )
#    1473         return buf.getvalue()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
df
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/Library/Python/3.7/lib/python/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/Library/Python/3.7/lib/python/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __repr__(self)
#    1469             min_rows=min_rows,
#    1470             max_rows=max_rows,
# -> 1471             length=show_dimensions,
#    1472         )
#    1473         return buf.getvalue()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1532             max_rows=max_rows,
#    1533         )
# -> 1534         result = formatter.to_string()
#    1535
#    1536         # catch contract violations
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     389
#     390         fmt_index, have_header = self._get_formatted_index()
# --> 391         fmt_values = self._get_formatted_values()
#     392
#     393         if self.is_truncated_vertically:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatted_values(self)
#     378             float_format=self.float_format,
#     379             na_rep=self.na_rep,
# --> 380             leading_space=self.index,
#     381         )
#     382
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1238     )
#    1239
# -> 1240     return fmt_obj.get_result()
#    1241
#    1242
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self)
#    1269
#    1270     def get_result(self) -> list[str]:
# -> 1271         fmt_values = self._format_strings()
#    1272         return _make_fixed_width(fmt_values, self.justify)
#    1273
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1332         for i, v in enumerate(vals):
#    1333             if not is_float_type[i] and leading_space:
# -> 1334                 fmt_values.append(f" {_format(v)}")
#    1335             elif is_float_type[i]:
#    1336                 fmt_values.append(float_format(v))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/formats/format.py in _format(x)
#    1309                 return self.na_rep
#    1310             elif isinstance(x, PandasObject):
# -> 1311                 return str(x)
#    1312             else:
#    1313                 # object dtype
#
# ... last 8 frames repeated, from the frame below ...
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __repr__(self)
#    1469             min_rows=min_rows,
#    1470             max_rows=max_rows,
# -> 1471             length=show_dimensions,
#    1472         )
#    1473         return buf.getvalue()
#
# RecursionError: maximum recursion depth exceeded in __instancecheck__

# %%
df
# Out:
#       company_name                                           job_name  \
# 0   Get Your Guide  Senior Data Analyst, Business Analytics (Suppl...
# 1           Amazon          Applied Scientist (MT), ASIN Localization
# 2         Autodesk                              AI Research Scientist
# 3            Tesla    Data Analyst Supply Chain (m/w/d) - Gigafactory
# 4          Zalando                       Data Engineer - Partner Tech
# ..             ...                                                ...
# 56          epilot                               Senior Data Engineer
# 57         Zalando                           Senior Applied Scientist
# 58         Zalando                           Senior Applied Scientist
# 59         Zalando         Applied Scientist (Marketing Intelligence)
# 60           adjoe                              Senior Data Scientist
#
#                                              job_desc  \
# 0   *What you'll do: You will be focusing on uncov...
# 1   *What you'll do: You will focus on delivering ...
# 2   *What you'll do: You will be doing fundamental...
# 3   *What you'll do: You will be working on delive...
# 4   *What you'll do: You will support the implemen...
# ..                                                ...
# 56  *What you'll do: You will build pipelines to e...
# 57  *What you'll do: You will be working on tailor...
# 58  *What you'll do: You will be working on implem...
# 59  *What you'll do: You will ensure the optimal a...
# 60  *What you'll do: You will work on ML models to...
#
#                                      job_req_and_info
# 0   [Berlin, DE, Visa sponsorship, in English, Pyt...
# 1   [Berlin, DE, Visa sponsorship, in English, Pyt...
# 2   [Munich, DE, Visa sponsorship, in English, Pyt...
# 3   [Berlin, DE, Visa sponsorship, in English, Pyt...
# 4   [Berlin, DE, Visa sponsorship, in English, Pyt...
# ..                                                ...
# 56  [Cologne, DE, Visa sponsorship, in English, Py...
# 57  [Berlin, DE, Visa sponsorship, in English, Pyt...
# 58  [Dortmund, DE, Visa sponsorship, in English, P...
# 59  [Berlin, DE, Visa sponsorship, in English, Pyt...
# 60  [Hamburg, DE, Visa sponsorship, in English, Py...
#
# [61 rows x 4 columns]
